# %% [markdown]
# <a href="https://colab.research.google.com/github/77-SP/Financial--Analysis--Phyton--Basics/blob/main/Exercise1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 1

# %%
buy_price = 200
sell_price = 250

profit = sell_price - buy_price
return_percent = (profit / buy_price) * 100

print("Profit:", profit)
print("Return (%):", return_percent)
# Out:
# Profit: 50
# Return (%): 25.0

# %%
buy_price=500
sell_price=450
profit=sell_price-buy_price
return_percent=(profit/buy_price)*100
print("Profit:",profit)
print("Return (%):",return_percent)
if sell_price>buy_price:
  print("Profit")
else:
  print("loss")
# Out:
# Profit: -50
# Return (%): -10.0
# loss

# %% [markdown]
# # New Section
